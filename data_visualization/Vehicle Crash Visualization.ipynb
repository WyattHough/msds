# %%
import altair as alt
import pandas as pd

data= pd.read_csv("bad-drivers/bad-drivers.csv")
data.head()
# Out:
#         State  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Number of drivers involved in fatal collisions per billion miles  \
# 0                                               18.8
# 1                                               18.1
# 2                                               18.6
# 3                                               22.4
# 4                                               12.0
#
#    Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# 0                                                 39
# 1                                                 41
# 2                                                 35
# 3                                                 18
# 4                                                 35
#
#    Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired  \
# 0                                                 30
# 1                                                 25
# ...

# %%
data.columns = ['State', 
                'Fatal Collisions (per billion mi.)', 
                'Speeding (%)',
                'Alcohol-Imparied (%)',
                'Not Distracted (%)',
                'No Previous Accidents (%)',
                'Insurance Premiums ($)',
                'Losses per Collision ($)']
data.head()
# Out:
#         State  Fatal Collisions (per billion mi.)  Speeding (%)  \
# 0     Alabama                                18.8            39
# 1      Alaska                                18.1            41
# 2     Arizona                                18.6            35
# 3    Arkansas                                22.4            18
# 4  California                                12.0            35
#
#    Alcohol-Imparied (%)  Not Distracted (%)  No Previous Accidents (%)  \
# 0                    30                  96                         80
# 1                    25                  90                         94
# 2                    28                  84                         96
# 3                    26                  94                         95
# 4                    28                  91                         89
#
#    Insurance Premiums ($)  Losses per Collision ($)
# 0                  784.55                    145.08
# ...

# %%
# Implementing selection
selection = alt.selection(type='multi', fields=['State'], on='mouseover', nearest=True)

alt.Chart(data).mark_circle().encode(
    x = "Total (per billion mi.)",
    y    = "Speeding (%)",
    color=alt.Color('State', scale=alt.Scale(scheme='spectral')),
    size="Insurance Premiums ($)",
    tooltip=["Not Distracted (%)"],
    opacity=alt.condition(selection,alt.value(1),alt.value(.2))
).add_selection(selection)
# Out:
# alt.Chart(...)
