# %% [markdown]
# # Week 3 CNN Cancer Detection Kaggle Mini-Project

# %% [markdown]
# ## Description

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Model and Results

# %% [markdown]
# ## Conclusion
